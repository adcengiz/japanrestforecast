# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import functools
from scipy.spatial.distance import cdist

# %matplotlib inline

# %% [markdown]
# ### Kernels and Kernel Machines

# %%
### Kernel function generators
def linear_kernel(X1, X2):
    """
    Computes the linear kernel between two sets of vectors.
    Args:
        X1 - an n1xd matrix with vectors x1_1,...,x1_n1 in the rows
        X2 - an n2xd matrix with vectors x2_1,...,x2_n2 in the rows
    Returns:
        matrix of size n1xn2, with x1_i^T x2_j in position i,j
    """
    return np.dot(X1,np.transpose(X2))
 
def RBF_kernel(X1,X2,sigma):
    """
    Computes the RBF kernel between two sets of vectors   
    Args:
        X1 - an n1xd matrix with vectors x1_1,...,x1_n1 in the rows
        X2 - an n2xd matrix with vectors x2_1,...,x2_n2 in the rows
        sigma - the bandwidth (i.e. standard deviation) for the RBF/Gaussian kernel
    Returns:
        matrix of size n1xn2, with exp(-||x1_i-x2_j||^2/(2 sigma^2)) in position i,j
    """
    norm_matrix = cdist(X1, X2, 'sqeuclidean')
    
    rbf_kernel_matrix = np.exp(-norm_matrix/(2*(sigma**2)))
    
    return rbf_kernel_matrix

def polynomial_kernel(X1, X2, offset, degree):
    """
    Computes the inhomogeneous polynomial kernel between two sets of vectors
    Args:
        X1 - an n1xd matrix with vectors x1_1,...,x1_n1 in the rows
        X2 - an n2xd matrix with vectors x2_1,...,x2_n2 in the rows
        offset, degree - two parameters for the kernel
    Returns:
        matrix of size n1xn2, with (offset + <x1_i,x2_j>)^degree in position i,j
    """
    offset_matrix = offset*np.ones\
    ((X1.shape[0], X2.shape[0]))
    
    polynom_kernel_matrix = np.power\
    ((offset_matrix + linear_kernel(X1, X2)), degree)
    
    return polynom_kernel_matrix

# %%
# Plot kernel machine functions

plot_step = .01
xpts = np.arange(-6.0, 6, plot_step).reshape(-1,1)
prototypes = np.array([-4,-1,0,2]).reshape(-1,1)

# Linear kernel
y = linear_kernel(prototypes, xpts)
plt.figure(figsize=(20,10))
for i in range(len(prototypes)):
    label = "Linear@"+str(prototypes[i,:])
    plt.plot(xpts, y[i,:], label=label, linewidth=3,alpha=0.7)
    plt.rcParams['font.size'] = 14
    plt.title('Linear Kernel Functions')
plt.legend(loc = 'best')
plt.show() 
 
# Polynomial kernel
y = polynomial_kernel(prototypes, xpts, 1, 3) 
plt.figure(figsize=(20,10))
for i in range(len(prototypes)):
    label = "Polynomial@"+str(prototypes[i,:])
    plt.plot(xpts, y[i,:], label=label, linewidth=3, alpha=0.7)
    plt.rcParams['font.size'] = 14
    plt.title('Polynomial Kernel Functions')
plt.legend(loc = 'best')
plt.show() 

# RBF kernel
y = RBF_kernel(prototypes, xpts, 1) 
plt.figure(figsize=(20,10))
for i in range(len(prototypes)):
    label = "RBF@"+str(prototypes[i,:])
    plt.plot(xpts, y[i,:], label=label, linewidth=3, alpha=0.7)
    plt.rcParams['font.size'] = 14
    plt.title('RBF Kernel Functions')
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# ### Initial Kernel Machine

# %%
class Kernel_Machine(object):
    def __init__(self, kernel, prototype_points, weights):
        self.kernel = kernel
        self.prototype_points = prototype_points
        self.weights = weights
    def predict(self, X):
        """
        Evaluates the kernel machine on the points given by the rows of X
        Args:
            X - an nxd matrix with inputs x_1,...,x_n in the rows
        Returns:
            Vector of kernel machine evaluations on the n points in X.  
            Specifically, jth entry of return vector is
                Sum_{i=1}^R w_i k(x_j, mu_i)
        """

        weights = np.array(self.weights).reshape(-1,1)
        prototype_points = np.array(self.prototype_points).reshape(-1,1)
        X = np.array(X)
        preds = []
        if self.kernel == "RBF":
            k = functools.partial(RBF_kernel, \
                                  X1=prototype_points, sigma=1)
            w_kernel_matrix=weights*k(X2=X)
            for i in w_kernel_matrix.T:
                preds.append(np.sum(i))
        elif self.kernel == "polynomial":
            k = functools.partial(polynomial_kernel, \
                                  X1=prototype_points,offset=1,degree=3)
            w_kernel_matrix = weights*k(X2=X)
            for i in w_kernel_matrix.T:
                preds.append(np.sum(i))
        elif self.kernel == "linear":
            k = functools.partial(linear_kernel, \
                                  X1=prototype_points)
            w_kernel_matrix = weights*k(X2=X)
            for i in w_kernel_matrix.T:
                preds.append(np.sum(i))
        return preds

# %%
plot_step = .1
xpts1 = np.arange(-6.0, 6, plot_step).reshape(-1,1)

Kernel_Machine(kernel="polynomial", prototype_points=[-1,0,1],\
               weights = [1,-1,1]).predict(xpts1)[:5]
# Out:
# [217.0,
#  209.86000000000004,
#  202.84000000000003,
#  195.94000000000008,
#  189.16000000000014]

# %%
## plot the kernel machine predictions
kernels = ["linear", "RBF", "polynomial"]
colors = ['blue', 'crimson', 'magenta']
for i in range(len(kernels)):
    plt.figure(i)
    plt.figure(figsize=(20,10))
    plt.plot(Kernel_Machine(kernel=kernels[i], prototype_points=[-1,0,1],\
               weights = [1,-1,1]).predict(xpts1), linewidth=4, alpha=0.6,\
            color=colors[i])
    plt.title(str(kernels[i]))
    plt.legend()
# Out:
# /Users/derin/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ###  Loading and Plotting the Training Data

# %%
data_train = np.loadtxt('krr-train.txt')
data_test = np.loadtxt('krr-test.txt')

X_train = np.array(data_train[:,0]).reshape(-1,1)
y_train = np.array(data_train[:,1]).reshape(-1,1)

X_test = np.array(data_test[:,0]).reshape(-1,1)
y_test = np.array(data_test[:,1]).reshape(-1,1)

# %%
# Training Data
plt.figure(figsize=(20,10))
plt.rcParams['font.size'] = 16
plt.scatter(X_train, y_train, s=120, color='b', alpha=0.6)
plt.title('The Training Data')
plt.xlabel('X_train')
plt.ylabel('y_train')

# %% [markdown]
# ### train_kernel_ridge_regression

# %%
def train_kernel_ridge_regression(X, y, kernel, l2reg, sigma=None, offset=None, degree=None):

    if (kernel == "RBF"):
        kernel_matrix = RBF_kernel(X, X, sigma=sigma)
    elif (kernel == "linear"):
        kernel_matrix = linear_kernel(X, X)
    elif (kernel == "polynomial"):
        kernel_matrix = polynomial_kernel(X, X, \
                                          offset=offset, degree=degree)
        
    alpha = np.dot(np.linalg.inv\
                   (l2reg*np.identity(len(kernel_matrix))+\
                    kernel_matrix), y)
    
    return Kernel_Machine(kernel, prototype_points=X, weights=alpha)

# %%
plt.figure(figsize=(20,10))
plt.rcParams['font.size'] = 16
plt.scatter(X_train, train_kernel_ridge_regression\
            (X_train, y_train, "RBF", l2reg=0.01,sigma=1).predict(X_train),\
            s=100, color='r', alpha=0.6, label='Prediction')
plt.scatter(X_train, y_train,s=100, color='b', alpha=0.6, label='Training Data')
plt.title('RBF Kernel Ridge Prediction on the Training Data')
plt.legend()

# %%
plt.figure(figsize=(20,10))
plt.rcParams['font.size'] = 16
plt.scatter(X_train, train_kernel_ridge_regression\
            (X_train, y_train, "polynomial", l2reg=0.01,offset=0, degree=1).predict(X_train),\
            s=100, color='r', alpha=0.6, label='Prediction')
plt.scatter(X_train, y_train,s=100, color='b', alpha=0.6, label='Training Data')
plt.title('Polynomial Kernel Ridge Prediction on the Training Data')
plt.legend()

# %%
plt.figure(figsize=(20,10))
plt.rcParams['font.size'] = 16
plt.scatter(X_train, train_kernel_ridge_regression\
            (X_train, y_train, "linear", l2reg=0.01).predict(X_train),\
            s=100, color='r', alpha=0.6, label='Prediction')
plt.scatter(X_train, y_train,s=100, color='b', alpha=0.6, label='Training Data')
plt.title('Linear (Kernel Ridge) Prediction on the Training Data')
plt.legend()

# %% [markdown]
# ### Hyperparameter Search for Both Sigma & Lambda

# %%
from sklearn.base import BaseEstimator, RegressorMixin, ClassifierMixin
class KernelRidgeRegression(BaseEstimator, RegressorMixin):  
    def __init__(self, kernel="RBF", sigma=1, degree=2, offset=1, l2reg=1):        
        self.kernel = kernel
        self.sigma = sigma
        self.degree = degree
        self.offset = offset
        self.l2reg = l2reg 
    def fit(self, X, y=None):
        if (self.kernel =="RBF"):
            self.kernel_machine_ = \
            train_kernel_ridge_regression(X, y, "RBF", \
                                          l2reg=self.l2reg, sigma=self.sigma,\
                                          degree=None, offset=None)
        elif (self.kernel =="linear"):
            self.kernel_machine_ = \
            train_kernel_ridge_regression(X, y, "linear", \
                                          l2reg=self.l2reg, sigma=None, \
                                          degree=None, offset=None)
        
        elif (self.kernel =="polynomial"):
            self.kernel_machine_ = \
            train_kernel_ridge_regression(X, y, "polynomial", \
                                          l2reg=self.l2reg, sigma=None,\
                                          degree=self.degree, offset=self.offset)
        else:
            raise ValueError('Unrecognized kernel type requested.')
        return self
    def predict(self, X, y=None):
        try:
            getattr(self, "kernel_machine_")
        except AttributeError:
            raise RuntimeError("You must train \
            classifer before predicting data!")

        return(self.kernel_machine_.predict(X))
    def score(self, X, y=None):
        # get the average square error
        return((self.predict(X)-y).mean())

# %%
from sklearn.model_selection import GridSearchCV,PredefinedSplit
from sklearn.model_selection import ParameterGrid
from sklearn.metrics import mean_squared_error,make_scorer
import pandas as pd
    
test_fold = [-1]*len(X_train) + [0]*len(X_test)   
#0 corresponds to test, -1 to train
predefined_split = PredefinedSplit(test_fold=test_fold)

# %%
from collections import Counter

# %%
## grid search
param_grid = [{'kernel': ['RBF'],'sigma':[.1,1,10], \
               'l2reg': np.exp2(-np.arange(-5,5,1))},
              {'kernel':['polynomial'],'offset':[-1,0,1], \
               'degree':[2,3,4],'l2reg':[10, .1, .01] },
              {'kernel':['linear'],'l2reg': [10,1,.01]}]
kernel_ridge_regression_estimator = KernelRidgeRegression()
grid = GridSearchCV(kernel_ridge_regression_estimator, 
                    param_grid,
                    cv = predefined_split,
                    scoring = make_scorer(mean_squared_error,\
                                          greater_is_better = False)
                   )
grid.fit(np.vstack((X_train,X_test)),np.vstack((y_train,y_test)))
# Out:
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#        error_score='raise',
#        estimator=KernelRidgeRegression(degree=2, kernel='RBF', l2reg=1, offset=1, sigma=1),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid=[{'kernel': ['RBF'], 'sigma': [0.1, 1, 10], 'l2reg': array([ 32.    ,  16.    ,   8.    ,   4.    ,   2.    ,   1.    ,
#          0.5   ,   0.25  ,   0.125 ,   0.0625])}, {'kernel': ['polynomial'], 'offset': [-1, 0, 1], 'degree': [2, 3, 4], 'l2reg': [10, 0.1, 0.01]}, {'kernel': ['linear'], 'l2reg': [10, 1, 0.01]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=make_scorer(mean_squared_error, greater_is_better=False),
#        verbose=0)

# %%
pd.set_option('display.max_rows', 20)
df = pd.DataFrame(grid.cv_results_)
# Flip sign of score back, because GridSearchCV likes to maximize,
# so it flips the sign of the score if "greater_is_better=FALSE"
df['mean_test_score'] = -df['mean_test_score']
df['mean_train_score'] = -df['mean_train_score']
cols_to_keep = ["param_degree", "param_kernel","param_l2reg"\
                ,"param_offset","param_sigma",
        "mean_test_score","mean_train_score"]
df_toshow = df[cols_to_keep].fillna('-')
df_toshow.sort_values(by=["mean_test_score"])
# Out:
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#    param_degree param_kernel  param_l2reg param_offset param_sigma  \
# 28            -          RBF       0.0625            -           1
# 44            3   polynomial       0.1000            1           -
# 47            3   polynomial       0.0100            1           -
# 25            -          RBF       0.1250            -           1
# 22            -          RBF       0.2500            -           1
# 19            -          RBF       0.5000            -           1
# 16            -          RBF       1.0000            -           1
# 41            3   polynomial      10.0000            1           -
# 13            -          RBF       2.0000            -           1
# 10            -          RBF       4.0000            -           1
# ..          ...          ...          ...          ...         ...
# 36            2   polynomial       0.0100           -1           -
# 54            4   polynomial       0.0100           -1           -
# 29            -          RBF       0.0625            -          10
# 51            4   polynomial       0.1000           -1           -
# 34            2   polynomial       0.1000            0           -
# 43            3   polynomial       0.1000            0           -
# 52            4   polynomial       0.1000            0           -
# 37            2   polynomial       0.0100            0           -
# 46            3   polynomial       0.0100            0           -
# 55            4   polynomial       0.0100            0           -
#
#     mean_test_score  mean_train_score
# 28     6.363177e-02      9.884273e-02
# 44     6.750775e-02      9.754616e-02
# 47     6.892663e-02      9.691253e-02
# 25     7.025240e-02      1.081655e-01
# 22     8.452570e-02      1.247461e-01
# 19     1.043390e-01      1.459140e-01
# 16     1.235387e-01      1.656641e-01
# 41     1.267084e-01      1.682928e-01
# 13     1.379683e-01      1.803044e-01
# 10     1.476088e-01      1.901032e-01
# ..              ...               ...
# 36     1.708963e+02      1.643175e+02
# 54     1.779699e+02      1.699199e+02
# 29     2.641754e+02      2.631076e+02
# 51     3.782270e+02      3.638354e+02
# 34     1.782933e+04      1.795251e+04
# 43     4.056495e+04      4.062521e+04
# 52     5.074931e+04      5.072830e+04
# 37     1.821389e+06      1.833566e+06
# 46     4.163372e+06      4.168760e+06
# 55     5.246970e+06      5.243723e+06
#
# [60 rows x 7 columns]

# %% [markdown]
# ### Another Zoomed-In Grid

# %%
param_grid = [{'kernel': ['RBF'],\
               'sigma':np.linspace(0.5,1.5, 100), \
               'l2reg': np.exp2(-np.linspace(3.7,4.2,100))},
              {'kernel':['polynomial'],\
               'offset':np.linspace(0.5, 1.5, 100), \
               'degree':[2,3,4],'l2reg':np.linspace(0.05, 0.15, 100) },
              {'kernel':['linear'],'l2reg':np.linspace(0.7, 1.3, 100)}]
kernel_ridge_regression_estimator = KernelRidgeRegression()
grid = GridSearchCV(kernel_ridge_regression_estimator, 
                    param_grid,
                    cv = predefined_split,
                    scoring = make_scorer(mean_squared_error,\
                                          greater_is_better = False)
                   )
grid.fit(np.vstack((X_train,X_test)),np.vstack((y_train,y_test)))
# Out:
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#        error_score='raise',
#        estimator=KernelRidgeRegression(degree=2, kernel='RBF', l2reg=1, offset=1, sigma=1),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid=[{'kernel': ['RBF'], 'sigma': array([ 0.5   ,  0.5101, ...,  1.4899,  1.5   ]), 'l2reg': array([ 0.07695,  0.07668, ...,  0.0546 ,  0.05441])}, {'kernel': ['polynomial'], 'offset': array([ 0.5   ,  0.5101, ...,  1.4899,  1.5   ]), 'degree': [2, 3, 4], 'l2reg': array([ 0.05   ,  0.05101, ...,  0.14899,  0.15   ])}, {'kernel': ['linear'], 'l2reg': array([ 0.7    ,  0.70606, ...,  1.29394,  1.3    ])}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=make_scorer(mean_squared_error, greater_is_better=False),
#        verbose=0)

# %%
pd.set_option('display.max_rows', 20)
df = pd.DataFrame(grid.cv_results_)
# Flip sign of score back, because GridSearchCV likes to maximize,
# so it flips the sign of the score if "greater_is_better=FALSE"
df['mean_test_score'] = -df['mean_test_score']
df['mean_train_score'] = -df['mean_train_score']
cols_to_keep = ["param_degree", "param_kernel",\
                "param_l2reg" ,"param_offset","param_sigma",
        "mean_test_score","mean_train_score"]
df_toshow = df[cols_to_keep].fillna('-')
df_toshow.sort_values(by=["mean_test_score"])
# Out:
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#       param_degree param_kernel  param_l2reg param_offset param_sigma  \
# 9950             -          RBF     0.054409            -     1.00505
# 9850             -          RBF     0.054600            -     1.00505
# 9750             -          RBF     0.054792            -     1.00505
# 9650             -          RBF     0.054984            -     1.00505
# 9550             -          RBF     0.055177            -     1.00505
# 9450             -          RBF     0.055370            -     1.00505
# 9350             -          RBF     0.055564            -     1.00505
# 9250             -          RBF     0.055759            -     1.00505
# 9150             -          RBF     0.055955            -     1.00505
# 9050             -          RBF     0.056151            -     1.00505
# ...            ...          ...          ...          ...         ...
# 10298            2   polynomial     0.052020       1.4899           -
# 10299            2   polynomial     0.052020          1.5           -
# 10095            2   polynomial     0.050000       1.4596           -
# 10197            2   polynomial     0.051010       1.4798           -
# 10198            2   polynomial     0.051010       1.4899           -
# 10096            2   polynomial     0.050000       1.4697           -
# 10199            2   polynomial     0.051010          1.5           -
# 10097            2   polynomial     0.050000       1.4798           -
# 10098            2   polynomial     0.050000       1.4899           -
# 10099            2   polynomial     0.050000          1.5           -
#
#        mean_test_score  mean_train_score
# 9950          0.062084          0.098304
# 9850          0.062096          0.098328
# 9750          0.062109          0.098352
# 9650          0.062122          0.098376
# 9550          0.062135          0.098400
# 9450          0.062148          0.098424
# 9350          0.062161          0.098449
# 9250          0.062174          0.098473
# 9150          0.062188          0.098498
# 9050          0.062201          0.098522
# ...                ...               ...
# 10298        35.225285         32.807397
# 10299        35.343758         32.921698
# 10095        35.345379         32.906308
# 10197        35.345568         32.915052
# 10198        35.465706         33.030957
# 10096        35.468443         33.025024
# 10199        35.584660         33.145728
# 10097        35.590282         33.142568
# 10098        35.710913         33.258955
# 10099        35.830353         33.374203
#
# [40100 rows x 7 columns]

# %%
## Plot the best polynomial and RBF fits you found
plot_step = .01
xpts = np.arange(-.5 , 1.5, plot_step).reshape(-1,1)
plt.rcParams['font.size'] = 16
plt.figure(figsize=(20,10))
plt.plot(X_train,y_train,'o', color='b', alpha=0.6)
#Plot best polynomial fit
## Getting the offset of the best polynomial fit ## offset = 
offset=df_toshow[df_toshow['param_kernel'] == "polynomial"].sort_values\
(by=["mean_test_score"])['param_offset'].iloc[0] 
## Getting the degree of the best polynomial fit ## degree = 
degree = df_toshow[df_toshow['param_kernel'] == "polynomial"].sort_values\
(by=["mean_test_score"])['param_degree'].iloc[0]
## Getting the l2reg of the best polynomial fit ## l2reg = 
l2reg = df_toshow[df_toshow['param_kernel'] == "polynomial"].sort_values\
(by=["mean_test_score"])['param_l2reg'].iloc[0]
# k = functools.partial(polynomial_kernel, offset=offset, degree=degree)
f = train_kernel_ridge_regression(X_train, y_train, "polynomial", l2reg=l2reg, offset=offset, degree=degree)
label = "Offset="+str(offset)+",Degree="+str(degree)+",L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label, linewidth=4, alpha=0.6, color='g')
plt.title('Best Polynomial Fit')
plt.legend()
###
### Plot best RBF fit
# Getting the sigma of the best polynomial fit ## sigma = 
sigma = df_toshow[df_toshow['param_kernel'] == "RBF"].sort_values\
(by=["mean_test_score"])['param_sigma'].iloc[0] 
# Getting the l2reg of the best polynomial fit ## l2reg = 
l2reg = df_toshow[df_toshow['param_kernel'] == "RBF"].sort_values\
(by=["mean_test_score"])['param_l2reg'].iloc[0] 

plt.rcParams['font.size'] = 16
plt.figure(figsize=(20,10))
plt.plot(X_train,y_train,'o', color='b', alpha=0.6)
# k = functools.partial(RBF_kernel, sigma=sigma)
f = train_kernel_ridge_regression(X_train, y_train, "RBF", l2reg=l2reg, sigma=sigma)
label = "Sigma="+str(sigma)+",L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label, linewidth=4, alpha=0.6, color='crimson')
plt.title('Best RBF Fit')
plt.legend(loc = 'best')
plt.ylim(-1,1.75)
plt.show()

### plotting RBF and Polynomial Together 
###
###

plot_step = .01
xpts = np.arange(-.5 , 1.5, plot_step).reshape(-1,1)
plt.rcParams['font.size'] = 16
plt.figure(figsize=(20,10))
plt.plot(X_train,y_train,'o', color='b', alpha=0.6)

offset=df_toshow[df_toshow['param_kernel'] == "polynomial"].sort_values\
(by=["mean_test_score"])['param_offset'].iloc[0] 
## Getting the degree of the best polynomial fit ## degree = 
degree = df_toshow[df_toshow['param_kernel'] == "polynomial"].sort_values\
(by=["mean_test_score"])['param_degree'].iloc[0]
## Getting the l2reg of the best polynomial fit ## l2reg = 
l2reg = df_toshow[df_toshow['param_kernel'] == "polynomial"].sort_values\
(by=["mean_test_score"])['param_l2reg'].iloc[0]
# k = functools.partial(polynomial_kernel, offset=offset, degree=degree)
f = train_kernel_ridge_regression(X_train, y_train, "polynomial", \
                                  l2reg=l2reg, offset=offset, degree=degree)
label = "Polynomial, " + "Offset="+str(offset)+",Degree="+str(degree)+\
",L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label, linewidth=4, alpha=0.6, \
         color='g')

sigma = df_toshow[df_toshow['param_kernel'] == "RBF"].sort_values\
(by=["mean_test_score"])['param_sigma'].iloc[0] 
# Getting the l2reg of the best polynomial fit ## l2reg = 
l2reg = df_toshow[df_toshow['param_kernel'] == "RBF"].sort_values\
(by=["mean_test_score"])['param_l2reg'].iloc[0] 
f = train_kernel_ridge_regression(X_train, y_train, "RBF", l2reg=l2reg,\
                                  sigma=sigma)
label =  "RBF, " + "Sigma="+str(sigma)+",L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label, linewidth=4, alpha=0.6, \
         color='crimson')

plt.title('Best RBF & Polynomial Fit')
plt.legend()

# %% [markdown]
# ### Zooming In More

# %%
param_grid = [{'kernel': ['RBF'],\
               'sigma':np.linspace(0.95,1.03, 50), \
               'l2reg': np.exp2(-np.linspace(4.17,4.25,100))},
              {'kernel':['polynomial'],\
               'offset':np.linspace(0.95, 1, 100), \
               'degree':[2,3,4],'l2reg':np.linspace(0.14, 0.18, 100) },
              {'kernel':['linear'],\
               'l2reg':np.linspace(1.2, 1.5, 100)}]
kernel_ridge_regression_estimator = KernelRidgeRegression()
grid = GridSearchCV(kernel_ridge_regression_estimator, 
                    param_grid,
                    cv = predefined_split,
                    scoring = make_scorer(mean_squared_error,\
                                          greater_is_better = False)
                   )
grid.fit(np.vstack((X_train,X_test)),np.vstack((y_train,y_test)))
# Out:
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#        error_score='raise',
#        estimator=KernelRidgeRegression(degree=2, kernel='RBF', l2reg=1, offset=1, sigma=1),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid=[{'kernel': ['RBF'], 'sigma': array([ 0.95   ,  0.95163,  0.95327,  0.9549 ,  0.95653,  0.95816,
#         0.9598 ,  0.96143,  0.96306,  0.96469,  0.96633,  0.96796,
#         0.96959,  0.97122,  0.97286,  0.97449,  0.97612,  0.97776,
#         0.97939,  0.98102,  0.98265,  0.98429,  0.98592,  ...,  0.18  ])}, {'kernel': ['linear'], 'l2reg': array([ 1.2    ,  1.20303, ...,  1.49697,  1.5    ])}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=make_scorer(mean_squared_error, greater_is_better=False),
#        verbose=0)

# %%
pd.set_option('display.max_rows', 20)
df = pd.DataFrame(grid.cv_results_)
# Flip sign of score back, because GridSearchCV likes to maximize,
# so it flips the sign of the score if "greater_is_better=FALSE"
df['mean_test_score'] = -df['mean_test_score']
df['mean_train_score'] = -df['mean_train_score']
cols_to_keep = ["param_degree", "param_kernel",\
                "param_l2reg" ,"param_offset","param_sigma",
        "mean_test_score","mean_train_score"]
df_toshow = df[cols_to_keep].fillna('-')
df_toshow.sort_values(by=["mean_test_score"])
# Out:
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#      param_degree param_kernel  param_l2reg param_offset param_sigma  \
# 4983            -          RBF     0.052556            -     1.00388
# 4933            -          RBF     0.052585            -     1.00388
# 4883            -          RBF     0.052615            -     1.00388
# 4833            -          RBF     0.052644            -     1.00388
# 4783            -          RBF     0.052674            -     1.00388
# 4733            -          RBF     0.052703            -     1.00388
# 4683            -          RBF     0.052733            -     1.00388
# 4984            -          RBF     0.052556            -     1.00551
# 4633            -          RBF     0.052762            -     1.00388
# 4934            -          RBF     0.052585            -     1.00551
# ...           ...          ...          ...          ...         ...
# 5197            2   polynomial     0.140404      0.99899           -
# 5093            2   polynomial     0.140000      0.99697           -
# 5198            2   polynomial     0.140404     0.999495           -
# 5094            2   polynomial     0.140000     0.997475           -
# 5199            2   polynomial     0.140404            1           -
# 5095            2   polynomial     0.140000      0.99798           -
# 5096            2   polynomial     0.140000     0.998485           -
# 5097            2   polynomial     0.140000      0.99899           -
# 5098            2   polynomial     0.140000     0.999495           -
# 5099            2   polynomial     0.140000            1           -
#
#       mean_test_score  mean_train_score
# 4983         0.061980          0.097726
# 4933         0.061982          0.097730
# 4883         0.061984          0.097733
# 4833         0.061986          0.097737
# 4783         0.061988          0.097741
# 4733         0.061990          0.097745
# 4683         0.061992          0.097748
# 4984         0.061992          0.098248
# 4633         0.061994          0.097752
# 4934         0.061994          0.098251
# ...               ...               ...
# 5197        17.032352         15.725067
# 5093        17.034186         15.725808
# 5198        17.039597         15.731987
# 5094        17.041458         15.732753
# 5199        17.046839         15.738903
# 5095        17.048725         15.739694
# 5096        17.055989         15.746631
# 5097        17.063248         15.753564
# 5098        17.070504         15.760493
# 5099        17.077755         15.767419
#
# [35100 rows x 7 columns]

# %%
## Plot the best polynomial and RBF fits you found
plot_step = .01
xpts = np.arange(-.5 , 1.5, plot_step).reshape(-1,1)
plt.rcParams['font.size'] = 16
plt.figure(figsize=(20,10))
plt.plot(X_train,y_train,'o', color='b', alpha=0.6)
#Plot best polynomial fit
## Getting the offset of the best polynomial fit ## offset = 
offset=df_toshow[df_toshow['param_kernel'] == "polynomial"].sort_values\
(by=["mean_test_score"])['param_offset'].iloc[0] 
## Getting the degree of the best polynomial fit ## degree = 
degree = df_toshow[df_toshow['param_kernel'] == "polynomial"].sort_values\
(by=["mean_test_score"])['param_degree'].iloc[0]
## Getting the l2reg of the best polynomial fit ## l2reg = 
l2reg = df_toshow[df_toshow['param_kernel'] == "polynomial"].sort_values\
(by=["mean_test_score"])['param_l2reg'].iloc[0]
# k = functools.partial(polynomial_kernel, offset=offset, degree=degree)
f = train_kernel_ridge_regression(X_train, y_train, "polynomial", \
                                  l2reg=l2reg, offset=offset, degree=degree)
label = "Offset="+str(offset)+",Degree="+str(degree)+",L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label, linewidth=4, alpha=0.6, color='orange')
plt.title('Best Polynomial Fit')
plt.legend()
###
### Plot best RBF fit
# Getting the sigma of the best polynomial fit ## sigma = 
sigma = df_toshow[df_toshow['param_kernel'] == "RBF"].sort_values\
(by=["mean_test_score"])['param_sigma'].iloc[0] 
# Getting the l2reg of the best polynomial fit ## l2reg = 
l2reg = df_toshow[df_toshow['param_kernel'] == "RBF"].sort_values\
(by=["mean_test_score"])['param_l2reg'].iloc[0] 

plt.rcParams['font.size'] = 16
plt.figure(figsize=(20,10))
plt.plot(X_train,y_train,'o', color='b', alpha=0.6)
# k = functools.partial(RBF_kernel, sigma=sigma)
f = train_kernel_ridge_regression(X_train, y_train, "RBF", \
                                  l2reg=l2reg, sigma=sigma)
label = "Sigma="+str(sigma)+",L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label, linewidth=4, \
         alpha=0.6, color='magenta')
plt.title('Best RBF Fit')
plt.legend(loc = 'best')
plt.ylim(-1,1.75)
plt.show()

### plotting RBF and Polynomial Together 
###
###
plot_step = .01
xpts = np.arange(-.5 , 1.5, plot_step).reshape(-1,1)
plt.rcParams['font.size'] = 16
plt.figure(figsize=(20,10))
plt.plot(X_train,y_train,'o', color='b', alpha=0.6)
offset=df_toshow[df_toshow['param_kernel'] == "polynomial"].sort_values\
(by=["mean_test_score"])['param_offset'].iloc[0] 
degree = df_toshow[df_toshow['param_kernel'] == "polynomial"].sort_values\
(by=["mean_test_score"])['param_degree'].iloc[0]
l2reg = df_toshow[df_toshow['param_kernel'] == "polynomial"].sort_values\
(by=["mean_test_score"])['param_l2reg'].iloc[0]
f = train_kernel_ridge_regression(X_train, y_train, "polynomial",\
                                  l2reg=l2reg, offset=offset, degree=degree)
label = "Polynomial, " + "Offset="+str(offset)+",Degree="+str(degree)+",L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label, linewidth=4, \
         alpha=0.6, color='orange')
sigma = df_toshow[df_toshow['param_kernel'] == "RBF"].sort_values\
(by=["mean_test_score"])['param_sigma'].iloc[0] 
# Getting the l2reg of the best polynomial fit ## l2reg = 
l2reg = df_toshow[df_toshow['param_kernel'] == "RBF"].sort_values\
(by=["mean_test_score"])['param_l2reg'].iloc[0] 
f = train_kernel_ridge_regression(X_train, y_train, "RBF", \
                                  l2reg=l2reg, sigma=sigma)
label =  "RBF, " + "Sigma="+str(sigma)+",L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label, linewidth=4, \
         alpha=0.6, color='magenta')
plt.title('Best RBF & Polynomial Fit')
plt.legend()

# %% [markdown]
# ### Trying New Kernels

# %%
## This is an addition to the "Kernel Generator
## Functions" part at the beginning
from math import sin 
def sin_kernel1(X1, X2):
    '''Returns
    matrix of size n1xn2, with exp(-2sin^k(||x - x'||/2)/p)
    in position i,j'''
    kernel_matrix = np.exp\
    (-np.power(2*np.sin(1/2*cdist(X1, X2, 'sqeuclidean')),2)/1)
    return kernel_matrix

def sin_kernel2(X1, X2):
    '''Returns
    matrix of size n1xn2, with exp(-2sin^k(||x - x'||/2)/p) 
    in position i,j'''
    kernel_matrix = np.exp\
    (-np.power(2*np.sin(1/2*cdist(X1, X2, 'sqeuclidean')),2)/3)
    return kernel_matrix
    
def sin_kernel3(X1, X2):
    '''Returns
    matrix of size n1xn2, with exp(-2sin^k(||x - x'||/2)/p) in 
    position i,j'''
    kernel_matrix = np.exp\
    (-np.power(2*np.sin(1/2*cdist(X1, X2, 'sqeuclidean')),3)/3)
    return kernel_matrix

def sin_kernel4(X1, X2):
    '''Returns
    matrix of size n1xn2, with exp(-2sin^k(||x - x'||/2)/p) 
    in position i,j'''
    kernel_matrix = np.exp\
    (-np.power(2*np.sin(1/2*cdist(X1, X2, 'euclidean')),2)/1)
    return kernel_matrix

# %%
plot_step = .01
xpts = np.arange(-6.0, 6, plot_step).reshape(-1,1)
prototypes = np.array([-4,-1,0,2]).reshape(-1,1)

# Some Other
y = sin_kernel4(prototypes, xpts)
plt.figure(figsize=(20,10))
for i in range(len(prototypes)):
    label = "Sin@"+str(prototypes[i,:])
    plt.plot(xpts, y[i,:], label=label, linewidth=3,alpha=0.7)
    plt.rcParams['font.size'] = 14
    plt.title('Some Other Kernel Functions')
plt.legend(loc = 'best')
plt.show()

# %%
## Modifying the Original Kernel Machine
class Kernel_Machine(object):
    def __init__(self, kernel, prototype_points, weights):
        self.kernel = kernel
        self.prototype_points = prototype_points
        self.weights = weights
    def predict(self, X):
        weights = np.array(self.weights).reshape(-1,1)
        prototype_points = np.array(self.prototype_points).reshape(-1,1)
        X = np.array(X)
        preds = []
        if self.kernel == "RBF":
            k = functools.partial(RBF_kernel, \
                                  X1=prototype_points, sigma=1)
            w_kernel_matrix=weights*k(X2=X)
            for i in w_kernel_matrix.T:
                preds.append(np.sum(i))
        elif self.kernel == "polynomial":
            k = functools.partial(polynomial_kernel, \
                                  X1=prototype_points,offset=1,degree=3)
            w_kernel_matrix = weights*k(X2=X)
            for i in w_kernel_matrix.T:
                preds.append(np.sum(i))
        elif self.kernel == "linear":
            k = functools.partial(linear_kernel, \
                                  X1=prototype_points)
            w_kernel_matrix = weights*k(X2=X)
            for i in w_kernel_matrix.T:
                preds.append(np.sum(i))
        elif self.kernel == "sin_kernel1":
            k = functools.partial(sin_kernel1, \
                                  X1=prototype_points)
            w_kernel_matrix = weights*k(X2=X)
            for i in w_kernel_matrix.T:
                preds.append(np.sum(i))
        elif self.kernel == "sin_kernel2":
            k = functools.partial(sin_kernel2, \
                                  X1=prototype_points)
            w_kernel_matrix = weights*k(X2=X)
            for i in w_kernel_matrix.T:
                preds.append(np.sum(i))
        elif self.kernel == "sin_kernel3":
            k = functools.partial(sin_kernel3, \
                                  X1=prototype_points)
            w_kernel_matrix = weights*k(X2=X)
            for i in w_kernel_matrix.T:
                preds.append(np.sum(i))
        elif self.kernel == "sin_kernel4":
            k = functools.partial(sin_kernel4, \
                                  X1=prototype_points)
            w_kernel_matrix = weights*k(X2=X)
            for i in w_kernel_matrix.T:
                preds.append(np.sum(i))
        return preds

# %%
## Modifying the Kernel Ridge Regression Class 
from sklearn.base import BaseEstimator, RegressorMixin, ClassifierMixin
class KernelRidgeRegression(BaseEstimator, RegressorMixin):  
    def __init__(self, kernel="RBF", sigma=1, degree=2, offset=1, l2reg=1):        
        self.kernel = kernel
        self.sigma = sigma
        self.degree = degree
        self.offset = offset
        self.l2reg = l2reg 
    def fit(self, X, y=None):
        if (self.kernel =="RBF"):
            self.kernel_machine_ = \
            train_kernel_ridge_regression\
            (X, y, "RBF", l2reg=self.l2reg, \
             sigma=self.sigma,degree=None, offset=None)
        elif (self.kernel =="linear"):
            self.kernel_machine_ = \
            train_kernel_ridge_regression\
            (X, y, "linear", l2reg=self.l2reg, \
             sigma=None,degree=None, offset=None)
        elif (self.kernel =="polynomial"):
            self.kernel_machine_ = \
            train_kernel_ridge_regression\
            (X, y, "polynomial", l2reg=self.l2reg,\
             sigma=None,degree=self.degree, offset=self.offset)
        elif (self.kernel == "sin_kernel1"):
            self.kernel_machine_ = \
            train_kernel_ridge_regression\
            (X, y, "sin_kernel1", l2reg=self.l2reg, \
             sigma=None,degree=None, offset=None)
        elif (self.kernel == "sin_kernel2"):
            self.kernel_machine_ = \
            train_kernel_ridge_regression\
            (X, y, "sin_kernel2", l2reg=self.l2reg, \
             sigma=None,degree=None, offset=None)
        elif (self.kernel == "sin_kernel3"):
            self.kernel_machine_ = \
            train_kernel_ridge_regression\
            (X, y, "sin_kernel3", l2reg=self.l2reg, \
             sigma=None,degree=None, offset=None)
        elif (self.kernel == "sin_kernel4"):
            self.kernel_machine_ = \
            train_kernel_ridge_regression\
            (X, y, "sin_kernel4", l2reg=self.l2reg, \
             sigma=None, degree=None, offset=None)
        else:
            raise ValueError('Unrecognized kernel type requested.')
        return self
    def predict(self, X, y=None):
        try:
            getattr(self, "kernel_machine_")
        except AttributeError:
            raise RuntimeError("You must train classifer \
            before predicting data!")
        return(self.kernel_machine_.predict(X))
    def score(self, X, y=None):
        # get the average square error
        return((self.predict(X)-y).mean())

# %%
def train_kernel_ridge_regression(X, y, kernel, l2reg, sigma=None, offset=None, degree=None):

    if (kernel == "RBF"):
        kernel_matrix = RBF_kernel(X, X, sigma=sigma)
    elif (kernel == "linear"):
        kernel_matrix = linear_kernel(X, X)
    elif (kernel == "polynomial"):
        kernel_matrix = polynomial_kernel(X, X, \
                                          offset=offset, degree=degree)
    elif (kernel == "sin_kernel1"):
        kernel_matrix  = sin_kernel1(X,X)
    elif (kernel == "sin_kernel2"):
        kernel_matrix  = sin_kernel2(X,X)
    elif (kernel == "sin_kernel3"):
        kernel_matrix  = sin_kernel3(X,X)
    elif (kernel == "sin_kernel4"):
        kernel_matrix  = sin_kernel4(X,X)
    
    alpha = np.dot(np.linalg.inv\
                   (l2reg*np.identity(len(kernel_matrix))+\
                    kernel_matrix), y)
    
    return Kernel_Machine(kernel, prototype_points=X, weights=alpha)

# %%
colors = ['b', 'r', 'c', 'm','g', 'y']
lambdas = [0.01, 0.1, 1]
plt.figure(figsize=(20,10))
plt.rcParams['font.size'] = 16
for i in range(len(lambdas)):
    plt.scatter(X_test, train_kernel_ridge_regression\
            (X_train, y_train, "sin_kernel1", \
             l2reg=lambdas[i],sigma=1).predict(X_test),\
            s=50, alpha=0.6, color=colors[i], \
                label='Lambda = '+ str(lambdas[i]))
plt.scatter(X_test, y_test,s=100, color='black', alpha=1, label='Training Data')
plt.title('New Kernel Ridge Prediction on the Training Data')
plt.legend()

# %% [markdown]
# ### Lambda Search for New Kernels

# %%
param_grid = [{'kernel': ['sin_kernel1'],'l2reg': np.linspace(0, 10, 100)},
              {'kernel':['sin_kernel2'],'l2reg':np.linspace(0, 10, 100) },
              {'kernel': ['sin_kernel3'],'l2reg': np.linspace(0, 10, 100)},
              {'kernel':['sin_kernel4'],'l2reg':np.linspace(0,10,100)}]
kernel_ridge_regression_estimator = KernelRidgeRegression()
grid = GridSearchCV(kernel_ridge_regression_estimator, 
                    param_grid,
                    cv = predefined_split,
                    scoring = make_scorer(mean_squared_error,\
                                          greater_is_better = False)
                   )
grid.fit(np.vstack((X_train,X_test)),np.vstack((y_train,y_test)))
# Out:
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#        error_score='raise',
#        estimator=KernelRidgeRegression(degree=2, kernel='RBF', l2reg=1, offset=1, sigma=1),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid=[{'kernel': ['sin_kernel1'], 'l2reg': array([  0.     ,   0.10101, ...,   9.89899,  10.     ])}, {'kernel': ['sin_kernel2'], 'l2reg': array([  0.     ,   0.10101, ...,   9.89899,  10.     ])}, {'kernel': ['sin_kernel3'], 'l2reg': array([  0.     ,   0.10101, ...,   9.89899,  10.     ])}, {'kernel': ['sin_kernel4'], 'l2reg': array([  0.     ,   0.10101, ...,   9.89899,  10.     ])}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=make_scorer(mean_squared_error, greater_is_better=False),
#        verbose=0)

# %%
pd.set_option('display.max_rows', 20)
df = pd.DataFrame(grid.cv_results_)
# Flip sign of score back, because GridSearchCV likes to maximize,
# so it flips the sign of the score if "greater_is_better=FALSE"
df['mean_test_score'] = -df['mean_test_score']
df['mean_train_score'] = -df['mean_train_score']
cols_to_keep = ["param_kernel","param_l2reg",
        "mean_test_score","mean_train_score"]
df_toshow = df[cols_to_keep].fillna('-')
df_toshow.sort_values(by=["mean_test_score"])
# Out:
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#     param_kernel  param_l2reg  mean_test_score  mean_train_score
# 1    sin_kernel1     0.101010         0.039811          0.058256
# 2    sin_kernel1     0.202020         0.049696          0.067204
# 301  sin_kernel4     0.101010         0.056029          0.086546
# 302  sin_kernel4     0.202020         0.057589          0.090625
# 303  sin_kernel4     0.303030         0.059975          0.094700
# 3    sin_kernel1     0.303030         0.060814          0.074298
# 304  sin_kernel4     0.404040         0.062881          0.098846
# 305  sin_kernel4     0.505051         0.066024          0.102939
# 101  sin_kernel2     0.101010         0.067556          0.085111
# 306  sin_kernel4     0.606061         0.069230          0.106893
# ..           ...          ...              ...               ...
# 209  sin_kernel3     0.909091        10.218172          8.688241
# 21   sin_kernel1     2.121212        14.505253         13.608954
# 18   sin_kernel1     1.818182        40.521343         36.879571
# 20   sin_kernel1     2.020202        54.376779         50.485366
# 0    sin_kernel1     0.000000       112.213829        111.949157
# 108  sin_kernel2     0.808081       204.876855        183.355975
# 208  sin_kernel3     0.808081       719.616892        592.256604
# 100  sin_kernel2     0.000000      1549.567438       1539.236774
# 300  sin_kernel4     0.000000     13552.670091      13617.236103
# 19   sin_kernel1     1.919192     69678.052370      64032.222612
#
# [400 rows x 4 columns]

# %%
## Best performing new kernels (l2reg search)
##
z_summary_df = \
pd.concat([df_toshow[df_toshow['param_kernel'] == "sin_kernel1"].sort_values\
(by=["mean_test_score"]).iloc[0],\
           df_toshow[df_toshow['param_kernel'] == "sin_kernel2"].sort_values\
(by=["mean_test_score"])\
           .iloc[0], df_toshow[df_toshow['param_kernel'] == "sin_kernel3"].sort_values\
(by=["mean_test_score"]).iloc[0], \
           df_toshow[df_toshow['param_kernel'] == "sin_kernel4"].sort_values\
(by=["mean_test_score"]).iloc[0]] ,1)
z_summary_df.T
# Out:
#     param_kernel param_l2reg mean_test_score mean_train_score
# 1    sin_kernel1     0.10101       0.0398112        0.0582559
# 101  sin_kernel2     0.10101       0.0675563        0.0851105
# 201  sin_kernel3     0.10101       0.0788748         0.094701
# 301  sin_kernel4     0.10101       0.0560294        0.0865459

# %% [markdown]
# ### Plotting the Best New Kernel Fits Against Different L2regs

# %%
plot_step = .01
xpts = np.arange(0 , 1, plot_step).reshape(-1,1)
plt.rcParams['font.size'] = 16
plt.figure(figsize=(20,10))
plt.plot(X_train,y_train,'o', color='b', alpha=0.6)
kernels = ['sin_kernel1', 'sin_kernel2', 'sin_kernel3', 'sin_kernel4']
## Getting the l2reg of the best sin1 fits
l2reg = df_toshow[df_toshow['param_kernel'] == "sin_kernel1"].sort_values\
(by=["mean_test_score"])['param_l2reg'].iloc[0]
f = train_kernel_ridge_regression(X_train, y_train, \
                                  "sin_kernel1", l2reg=l2reg, \
                                  offset=offset, degree=degree)
label = "Sin1, " +"L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label, linewidth=4, alpha=0.6, color='r')
## Getting the l2reg of the best sin2 fits
l2reg = df_toshow[df_toshow['param_kernel'] == \
                  "sin_kernel2"].sort_values\
(by=["mean_test_score"])['param_l2reg'].iloc[0]
f = train_kernel_ridge_regression(X_train, y_train, \
                                  "sin_kernel2", l2reg=l2reg, \
                                  offset=offset, degree=degree)
label = "Sin2, " +"L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label, linewidth=4, alpha=0.6, color='y')
## Getting the l2reg of the best sin3 fits
l2reg = df_toshow[df_toshow['param_kernel'] == \
                  "sin_kernel3"].sort_values\
(by=["mean_test_score"])['param_l2reg'].iloc[0]
f = train_kernel_ridge_regression(X_train, y_train, \
                                  "sin_kernel3", l2reg=l2reg, \
                                  offset=offset, degree=degree)
label = "Sin3, " +"L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label, linewidth=4, alpha=0.6, color='c')

## Getting the l2reg of the best sin4 fits
l2reg = df_toshow[df_toshow['param_kernel'] == \
                  "sin_kernel4"].sort_values\
(by=["mean_test_score"])['param_l2reg'].iloc[0]
f = train_kernel_ridge_regression(X_train, y_train, \
                                  "sin_kernel4", l2reg=l2reg, \
                                  offset=offset, degree=degree)
label = "Sin4, " +"L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label, linewidth=4, alpha=0.6, color='m')


plt.title('Best New Kernel Fits')
plt.legend()

# %%
## Zooming In
param_grid = [{'kernel': ['sin_kernel1'],'l2reg': np.linspace(0, 2, 100)},
              {'kernel':['sin_kernel2'],'l2reg':np.linspace(0, 2, 100) },
              {'kernel': ['sin_kernel3'],'l2reg': np.linspace(0, 2, 100)},
              {'kernel':['sin_kernel4'],'l2reg':np.linspace(0,2,100)}]
kernel_ridge_regression_estimator = KernelRidgeRegression()
grid = GridSearchCV(kernel_ridge_regression_estimator, 
                    param_grid,
                    cv = predefined_split,
                    scoring = make_scorer(mean_squared_error,\
                                          greater_is_better = False)

                   )
grid.fit(np.vstack((X_train,X_test)),np.vstack((y_train,y_test)))
# Out:
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#        error_score='raise',
#        estimator=KernelRidgeRegression(degree=2, kernel='RBF', l2reg=1, offset=1, sigma=1),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid=[{'kernel': ['sin_kernel1'], 'l2reg': array([ 0.    ,  0.0202, ...,  1.9798,  2.    ])}, {'kernel': ['sin_kernel2'], 'l2reg': array([ 0.    ,  0.0202, ...,  1.9798,  2.    ])}, {'kernel': ['sin_kernel3'], 'l2reg': array([ 0.    ,  0.0202, ...,  1.9798,  2.    ])}, {'kernel': ['sin_kernel4'], 'l2reg': array([ 0.    ,  0.0202, ...,  1.9798,  2.    ])}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=make_scorer(mean_squared_error, greater_is_better=False),
#        verbose=0)

# %%
pd.set_option('display.max_rows', 20)
df = pd.DataFrame(grid.cv_results_)
df['mean_test_score'] = -df['mean_test_score']
df['mean_train_score'] = -df['mean_train_score']
cols_to_keep = ["param_kernel","param_l2reg",
        "mean_test_score","mean_train_score"]
df_toshow = df[cols_to_keep].fillna('-')
df_toshow.sort_values(by=["mean_test_score"])
# Out:
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#     param_kernel  param_l2reg  mean_test_score  mean_train_score
# 1    sin_kernel1     0.020202         0.031020          0.043782
# 2    sin_kernel1     0.040404         0.032592          0.048401
# 3    sin_kernel1     0.060606         0.035043          0.052348
# 201  sin_kernel3     0.020202         0.035476          0.055181
# 4    sin_kernel1     0.080808         0.037506          0.055583
# 5    sin_kernel1     0.101010         0.039811          0.058256
# 202  sin_kernel3     0.040404         0.041654          0.066916
# 6    sin_kernel1     0.121212         0.041955          0.060509
# 101  sin_kernel2     0.020202         0.043030          0.064843
# 7    sin_kernel1     0.141414         0.043973          0.062456
# ..           ...          ...              ...               ...
# 93   sin_kernel1     1.878788       249.133135        228.041388
# 97   sin_kernel1     1.959596       348.656606        321.706632
# 241  sin_kernel3     0.828283       657.195852        544.109619
# 240  sin_kernel3     0.808081       719.616892        592.256604
# 94   sin_kernel1     1.898990       902.461672        827.685850
# 100  sin_kernel2     0.000000      1549.567438       1539.236774
# 96   sin_kernel1     1.939394      1580.311774       1455.194095
# 300  sin_kernel4     0.000000     13552.670091      13617.236103
# 95   sin_kernel1     1.919192     69678.052370      64032.222612
# 139  sin_kernel2     0.787879    451086.465363     401446.472786
#
# [400 rows x 4 columns]

# %%
param_grid = [{'kernel': ['sin_kernel1'],'l2reg': np.linspace(0, 1, 100)},
              {'kernel':['sin_kernel2'],'l2reg':np.linspace(0, 1, 100) },
              {'kernel': ['sin_kernel3'],'l2reg': np.linspace(0, 1, 100)},
              {'kernel':['sin_kernel4'],'l2reg':np.linspace(0,1,100)}]
kernel_ridge_regression_estimator = KernelRidgeRegression()
grid = GridSearchCV(kernel_ridge_regression_estimator, 
                    param_grid,
                    cv = predefined_split,
                    scoring = make_scorer(mean_squared_error,\
                                          greater_is_better = False)
                   )
grid.fit(np.vstack((X_train,X_test)),np.vstack((y_train,y_test)))
# Out:
# GridSearchCV(cv=PredefinedSplit(test_fold=array([-1, -1, ...,  0,  0])),
#        error_score='raise',
#        estimator=KernelRidgeRegression(degree=2, kernel='RBF', l2reg=1, offset=1, sigma=1),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid=[{'kernel': ['sin_kernel1'], 'l2reg': array([ 0.    ,  0.0101, ...,  0.9899,  1.    ])}, {'kernel': ['sin_kernel2'], 'l2reg': array([ 0.    ,  0.0101, ...,  0.9899,  1.    ])}, {'kernel': ['sin_kernel3'], 'l2reg': array([ 0.    ,  0.0101, ...,  0.9899,  1.    ])}, {'kernel': ['sin_kernel4'], 'l2reg': array([ 0.    ,  0.0101, ...,  0.9899,  1.    ])}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=make_scorer(mean_squared_error, greater_is_better=False),
#        verbose=0)

# %%
pd.set_option('display.max_rows', 20)
df = pd.DataFrame(grid.cv_results_)
df['mean_test_score'] = -df['mean_test_score']
df['mean_train_score'] = -df['mean_train_score']
cols_to_keep = ["param_kernel","param_l2reg",
        "mean_test_score","mean_train_score"]
df_toshow = df[cols_to_keep].fillna('-')
df_toshow.sort_values(by=["mean_test_score"])
# Out:
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/derin/anaconda/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#     param_kernel  param_l2reg  mean_test_score  mean_train_score
# 2    sin_kernel1     0.020202         0.031020          0.043782
# 3    sin_kernel1     0.030303         0.031574          0.046149
# 1    sin_kernel1     0.010101         0.031639          0.041517
# 4    sin_kernel1     0.040404         0.032592          0.048401
# 5    sin_kernel1     0.050505         0.033791          0.050470
# 201  sin_kernel3     0.010101         0.034792          0.048427
# 6    sin_kernel1     0.060606         0.035043          0.052348
# 202  sin_kernel3     0.020202         0.035476          0.055181
# 101  sin_kernel2     0.010101         0.036037          0.055338
# 7    sin_kernel1     0.070707         0.036290          0.054046
# ..           ...          ...              ...               ...
# 283  sin_kernel3     0.838384       173.484480        144.080503
# 180  sin_kernel2     0.808081       204.876855        183.355975
# 282  sin_kernel3     0.828283       657.195852        544.109619
# 177  sin_kernel2     0.777778       677.918370        601.665799
# 280  sin_kernel3     0.808081       719.616892        592.256604
# 179  sin_kernel2     0.797980       835.563175        745.686444
# 100  sin_kernel2     0.000000      1549.567438       1539.236774
# 300  sin_kernel4     0.000000     13552.670091      13617.236103
# 178  sin_kernel2     0.787879    451086.465363     401446.472786
# 281  sin_kernel3     0.818182    610818.527044     504185.223129
#
# [400 rows x 4 columns]

# %%
plot_step = .01
xpts = np.arange(0 , 1, plot_step).reshape(-1,1)
plt.rcParams['font.size'] = 16
plt.figure(figsize=(20,10))
plt.plot(X_train,y_train,'o', color='b', alpha=0.6)
kernels = ['sin_kernel1', 'sin_kernel2', \
           'sin_kernel3', 'sin_kernel4']
## Getting the l2reg of the best sin1 fits
l2reg = df_toshow[df_toshow['param_kernel'] == \
                  "sin_kernel1"].sort_values\
(by=["mean_test_score"])['param_l2reg'].iloc[0]
f = train_kernel_ridge_regression\
(X_train, y_train, "sin_kernel1", l2reg=l2reg, offset=offset, degree=degree)
label = "Sin1, " +"L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label, linewidth=4, alpha=0.6, color='r')
## Getting the l2reg of the best sin2 fits
l2reg = df_toshow[df_toshow['param_kernel'] == \
                  "sin_kernel2"].sort_values\
(by=["mean_test_score"])['param_l2reg'].iloc[0]
f = train_kernel_ridge_regression\
(X_train, y_train,"sin_kernel2", l2reg=l2reg, offset=offset, degree=degree)
label = "Sin2, " +"L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label, linewidth=4, alpha=0.6, color='y')
## Getting the l2reg of the best sin3 fits
l2reg = df_toshow[df_toshow['param_kernel'] == \
                  "sin_kernel3"].sort_values\
(by=["mean_test_score"])['param_l2reg'].iloc[0]
f = train_kernel_ridge_regression\
(X_train, y_train, "sin_kernel3", l2reg=l2reg, offset=offset, degree=degree)
label = "Sin3, " +"L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label, linewidth=4, alpha=0.6, color='c')

## Getting the l2reg of the best sin4 fits
l2reg = df_toshow[df_toshow['param_kernel'] == \
                  "sin_kernel4"].sort_values\
(by=["mean_test_score"])['param_l2reg'].iloc[0]
f = train_kernel_ridge_regression\
(X_train, y_train,"sin_kernel4", l2reg=l2reg, offset=offset, degree=degree)
label = "Sin4, " +"L2Reg="+str(l2reg)
plt.plot(xpts, f.predict(xpts), label=label, linewidth=4, alpha=0.6, color='m')


plt.title('Best New Kernel Fits')
plt.legend()

# %% [markdown]
# ### Weather Measurement Feature Construction Using RBF Kernels

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data_train = pd.DataFrame(pd.read_csv("data_train.csv"))
data_train = data_train.dropna(0)
data_test = pd.DataFrame(pd.read_csv("data_test.csv"))
data_test = data_test.dropna(0)

# %%
## preparing the data for Kernel Ridge Regression
kernel_X_df = data_train[[col for col in data_train.columns.values if col not in ["visitors","Unnamed: 0","visit_date", "air_store_id", "train_ind"]]]
kernel_X = np.array(kernel_X_df) ## use arrays while training model
kernel_y_df = data_train["visitors"]
kernel_y = np.array(kernel_y_df).reshape(-1,1) ## use arrays while training model

kernel_Xtest_df = data_test[[col for col in data_train.columns.values if col not in ["visitors","Unnamed: 0","visit_date", "air_store_id","train_ind"]]]
kernel_Xtest = np.array(kernel_Xtest_df) ## use arrays while training model
kernel_ytest_df = data_test["visitors"]
kernel_ytest = np.array(kernel_ytest_df).reshape(-1,1) ## use arrays while training model

# %%
# kernel_X_df.columns.values

# %%
kernel_cols = ['Friday', 'Monday', 'Saturday', 'Sunday', 'Thursday', 'Tuesday',
       'Wednesday', 'avg_temperature1', 'high_temperature1', 'holiday_flg',
       'hours_sunlight1', 'low_temperature1']

kernel_norm_cols = ['avg_temperature1', 'high_temperature1','hours_sunlight1', 'low_temperature1']

# %%
from sklearn.preprocessing import StandardScaler
rbf_scaler = StandardScaler()
RBF_weather_data = rbf_scaler.fit_transform(kernel_X_df[kernel_norm_cols])

# %%
RBF_weather_data = pd.DataFrame(RBF_weather_data, columns=kernel_norm_cols)

# %%
# RBF_weather_data

# %%
# RBF_kernel(np.array(RBF_weather_data), np.array(RBF_weather_data), sigma=1)
